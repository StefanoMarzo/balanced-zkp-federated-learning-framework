# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:31
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 4.9.2

# %%
# !git clone https://github.com/alibaba/FederatedScope.git
# Out:
# Cloning into 'FederatedScope'...
# remote: Enumerating objects: 2874, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 2874 (delta 11), reused 13 (delta 4), pack-reused 2829
# Receiving objects: 100% (2874/2874), 760.28 KiB | 1.68 MiB/s, done.
# Resolving deltas: 100% (1915/1915), done.

# %%
cd FederatedScope
# Out:
# /content/FederatedScope

# %%
# !conda install --file enviroment/requirements-torch1.10-application.txt -c pytorch -c conda-forge -c nvidia -c pyg
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# -
# CondaError: KeyboardInterrupt
#
# ^C

# %%
# !conda install --file enviroment/requirements-torch1.10.txt -c pytorch -c conda-forge -c nvidia
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# | WARNING conda.core.solve:_add_specs(611): pinned spec cudatoolkit=11.1 conflicts with explicit specs.  Overriding pinned spec.
# failed with initial frozen solve. Retrying with flexible solve.
# \ WARNING conda.core.solve:_add_specs(611): pinned spec cudatoolkit=11.1 conflicts with explicit specs.  Overriding pinned spec.
# /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - pandas==1.4.1 -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0']
#   - pytorch==1.10.1 -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.8.12|3.9.10|>=2.7,<2.8.0a0|>=3.5|>=3.6|>=3.7|>=3.5,<3.6.0a0|>=3.6,<3.7|>=3.10,<3.11.0a0|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.4.*|3.7.*|3.9.*|3.8.*',build='2_73_pypy|3_73_pypy|1_73_pypy|0_73_pypy|0_73_pypy|5_73_pypy|5_73_pypy|4_73_pypy|1_73_pypy|0_73_pypy']
#   - torchaudio==0.10.1 -> python[version='2.7.*|3.5.*|3.6.*|>=2.7,<2.8.0a0|>=3.10,<3.11.0a0|>=3.5,<3.6.0a0|3.4.*']
#
# Your python: python=3.7
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package termcolor conflicts for:
# fvcore -> termcolor[version='>=1.1']
# wandb -> yaspin[version='>=1.0.0'] -> termcolor[version='>=1.1.0,<2.0.0']
#
# Package libgcc-ng conflicts for:
# scipy==1.7.3 -> libgcc-ng[version='>=7.5.0|>=9.4.0']
# wandb -> protobuf[version='>=3.12.0'] -> libgcc-ng[version='>=10.3.0|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0|>=12']
# pytorch==1.10.1 -> libgcc-ng[version='>=7.5.0|>=9.4.0']
# scikit-learn==1.0.2 -> libcblas[version='>=3.8.0,<4.0a0'] -> libgcc-ng[version='>=10.3.0|>=12|>=7.3.0|>=9.3.0|>=4.9|>=7.2.0']
# python=3.7 -> libgcc-ng[version='>=4.9|>=7.3.0|>=7.5.0|>=9.3.0|>=9.4.0|>=7.2.0']
# tensorboard -> grpcio[version='>=1.24.3'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=4.9']
# grpcio-tools -> libgcc-ng[version='>=7.3.0|>=7.5.0|>=9.4.0']
# pandas==1.4.1 -> libgcc-ng[version='>=7.5.0|>=9.4.0']
# protobuf==3.19.4 -> libgcc-ng[version='>=9.4.0']
# torchaudio==0.10.1 -> cudatoolkit[version='>=11.1,<11.2'] -> libgcc-ng[version='>=10.3.0|>=9.4.0|>=9.3.0|>=7.3.0|>=12|>=7.5.0|>=4.9|>=7.2.0']
# tensorboardx -> numpy -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# numpy==1.21.2 -> libgcc-ng[version='>=7.5.0|>=9.4.0']
# python=3.7 -> libzlib[version='>=1.2.11,<1.3.0a0'] -> libgcc-ng[version='>=10.3.0|>=12']
# pandas==1.4.1 -> numpy[version='>=1.21.5,<2.0a0'] -> libgcc-ng[version='>=10.3.0|>=12|>=9.3.0|>=7.3.0']
# protobuf==3.19.4 -> python[version='>=3.10,<3.11.0a0'] -> libgcc-ng[version='>=10.3.0|>=7.5.0|>=12|>=9.3.0|>=7.3.0|>=4.9|>=7.2.0']
# fvcore -> numpy -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0|>=8.4.0']
# scipy==1.7.3 -> libblas[version='>=3.8.0,<4.0a0'] -> libgcc-ng[version='>=10.3.0|>=12|>=7.3.0|>=9.3.0|>=4.9|>=7.2.0|>=11.2.0']
# numpy==1.21.2 -> libblas[version='>=3.8.0,<4.0a0'] -> libgcc-ng[version='>=10.3.0|>=12|>=7.3.0|>=9.3.0|>=4.9|>=7.2.0|>=11.2.0']
# torchvision==0.11.2 -> libgcc-ng[version='>=7.5.0|>=9.4.0']
# grpcio-tools -> protobuf[version='>=3.6.0'] -> libgcc-ng[version='>=10.3.0|>=9.3.0|>=4.9|>=7.2.0|>=12']
# tensorboard -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# cudatoolkit==11.3.1 -> libgcc-ng[version='>=10.3.0|>=9.4.0|>=9.3.0']
# torchvision==0.11.2 -> cudatoolkit[version='>=11.1,<11.2'] -> libgcc-ng[version='>=10.3.0|>=9.3.0|>=7.3.0|>=12|>=7.2.0|>=4.9|>=8.4.0|>=3.0|>=5.4.0']
# grpcio -> libgcc-ng[version='>=10.3.0|>=12|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# pympler -> python -> libgcc-ng[version='>=10.3.0|>=9.4.0|>=12|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# scikit-learn==1.0.2 -> libgcc-ng[version='>=7.5.0|>=9.4.0']
# iopath -> python[version='>=3.6'] -> libgcc-ng[version='>=10.3.0|>=9.4.0|>=12|>=9.3.0|>=7.5.0|>=7.3.0|>=4.9|>=7.2.0']
# setuptools==61.2.0 -> pypy3.8[version='>=7.3.8'] -> libgcc-ng[version='>=10.3.0|>=9.4.0|>=9.3.0|>=7.5.0|>=7.3.0|>=12|>=4.9|>=7.2.0']
# pytorch==1.10.1 -> blas=[build=mkl] -> libgcc-ng[version='>=10.3.0|>=9.3.0|>=7.3.0|>=4.9|>=7.2.0|>=12|>=3.0']
#
# Package libgfortran conflicts for:
# fvcore -> numpy -> libgfortran[version='>=3.0']
# scikit-learn==1.0.2 -> scipy -> libgfortran[version='>=3.0']
# torchvision==0.11.2 -> numpy[version='>=1.11'] -> libgfortran[version='>=3.0']
# tensorboardx -> numpy -> libgfortran[version='>=3.0']
# torchaudio==0.10.1 -> numpy[version='>=1.11'] -> libgfortran[version='>=3.0']
# tensorboard -> numpy[version='>=1.12.0'] -> libgfortran[version='>=3.0']
#
# Package cython conflicts for:
# tensorboard -> grpcio[version='>=1.24.3'] -> cython
# wandb -> pyyaml -> cython
# grpcio-tools -> grpcio==1.35.0 -> cython
# grpcio -> cython
#
# Package pypy3.6 conflicts for:
# torchvision==0.11.2 -> numpy[version='>=1.11'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
# tensorboard -> absl-py[version='>=0.4'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
# protobuf==3.19.4 -> setuptools -> pypy3.6[version='>=7.3.1|>=7.3.2|>=7.3.3']
# scipy==1.7.3 -> numpy[version='>=1.19.5,<2.0a0'] -> pypy3.6[version='>=7.3.1|>=7.3.2|>=7.3.3']
# fvcore -> numpy -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
# torchaudio==0.10.1 -> numpy[version='>=1.11'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
# setuptools==61.2.0 -> certifi[version='>=2016.9.26'] -> pypy3.6[version='>=7.3.1|>=7.3.2|>=7.3.3']
# pandas==1.4.1 -> numpy[version='>=1.19.5,<2.0a0'] -> pypy3.6[version='>=7.3.1|>=7.3.2|>=7.3.3']
# grpcio -> setuptools -> pypy3.6[version='7.3.*|7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
# iopath -> portalocker -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
# pympler -> python -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*']
# pytorch==1.10.1 -> python[version='>=3.6,<3.7.0a0'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.3|>=7.3.2|>=7.3.1']
# wandb -> click[version='>=7.0,!=8.0.0'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
# scikit-learn==1.0.2 -> numpy[version='>=1.19.5,<2.0a0'] -> pypy3.6[version='>=7.3.1|>=7.3.2|>=7.3.3']
# tensorboardx -> numpy -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
# grpcio-tools -> protobuf[version='>=3.6.0'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*|>=7.3.1|>=7.3.2|>=7.3.3']
#
# Package certifi conflicts for:
# setuptools==61.2.0 -> certifi[version='>=2016.9.26']
# wandb -> requests[version='>=2.0.0,<3'] -> certifi[version='>=2016.09|>=2016.9.26|>=2017.4.17']
# protobuf==3.19.4 -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# tensorboard -> requests[version='>=2.21.0,<3'] -> certifi[version='>=2016.09|>=2016.9.26|>=2017.4.17']
# grpcio -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# pytorch==1.10.1 -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
#
# Package six conflicts for:
# grpcio-tools -> grpcio==1.41.1 -> six[version='>=1.5.2|>=1.6.0']
# scipy==1.7.3 -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# grpcio -> protobuf[version='>=3.5.0'] -> six
# numpy==1.21.2 -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# protobuf==3.19.4 -> six
# tensorboardx -> six
# pandas==1.4.1 -> python-dateutil[version='>=2.7.3'] -> six[version='>=1.5']
# wandb -> docker-pycreds[version='>=0.4.0'] -> six[version='>=1.4.0|>=1.5']
# wandb -> six[version='>=1.10.0|>=1.13.0']
# tensorboard -> google-auth[version='>=1.6.3,<3'] -> six[version='>=1.5.2|>=1.6.0|>=1.9.0|>=1.9.0,<2dev|>=1.9']
# grpcio -> six[version='>=1.5.2|>=1.6.0']
# tensorboard -> six[version='>=1.10.0|>=1.12']
#
# Package setuptools conflicts for:
# tensorboard -> google-auth[version='>=1.6.3,<3'] -> setuptools[version='>=36|>=40.3.0']
# protobuf==3.19.4 -> setuptools
# pytorch==1.10.1 -> setuptools
# wandb -> setuptools
# grpcio-tools -> grpcio==1.41.1 -> setuptools
# tensorboardx -> protobuf[version='>=3.8.0'] -> setuptools
# tensorboard -> setuptools[version='>=41.0.0|>=41.4']
# torchvision==0.11.2 -> pytorch==1.10.1 -> setuptools[version='<59.6']
# grpcio -> setuptools
# torchaudio==0.10.1 -> pytorch==1.10.1 -> setuptools
# pandas==1.4.1 -> numexpr[version='>=2.7.1'] -> setuptools
# scikit-learn==1.0.2 -> joblib[version='>=0.11'] -> setuptools
#
# Package protobuf conflicts for:
# grpcio -> protobuf[version='>=3.5.0']
# tensorboard -> grpcio[version='>=1.6.3'] -> protobuf[version='>=3.5.0']
# tensorboardx -> protobuf[version='>=0.3.2|>=3.2.0|>=3.8.0']
# grpcio-tools -> protobuf[version='>=3.6.0']
# wandb -> protobuf[version='>=3.12.0']
# tensorboard -> protobuf[version='>=3.3.0|>=3.4.0|>=3.6.0|>=3.9.2|>=3.8.0|>=3.6.1']
#
# Package _openmp_mutex conflicts for:
# tensorboard -> libgcc-ng[version='>=7.3.0'] -> _openmp_mutex[version='>=4.5']
# python=3.7 -> libgcc-ng[version='>=9.4.0'] -> _openmp_mutex[version='>=4.5']
# pytorch==1.10.1 -> blas=[build=mkl] -> _openmp_mutex=[build=*_llvm]
# grpcio -> libgcc-ng[version='>=12'] -> _openmp_mutex[version='>=4.5']
# protobuf==3.19.4 -> libgcc-ng[version='>=9.4.0'] -> _openmp_mutex[version='>=4.5']
# cudatoolkit==11.3.1 -> libgcc-ng[version='>=10.3.0'] -> _openmp_mutex[version='>=4.5']
# numpy==1.21.2 -> libgcc-ng[version='>=9.4.0'] -> _openmp_mutex[version='*|>=4.5',build=*_llvm]
# scikit-learn==1.0.2 -> libgcc-ng[version='>=9.4.0'] -> _openmp_mutex[version='>=4.5']
# torchaudio==0.10.1 -> pytorch==1.10.1 -> _openmp_mutex[version='>=4.5']
# pandas==1.4.1 -> libgcc-ng[version='>=9.4.0'] -> _openmp_mutex[version='>=4.5']
# scipy==1.7.3 -> libgcc-ng[version='>=9.4.0'] -> _openmp_mutex[version='*|>=4.5',build=*_llvm]
# scikit-learn==1.0.2 -> _openmp_mutex
# grpcio-tools -> libgcc-ng[version='>=9.4.0'] -> _openmp_mutex[version='>=4.5']
# torchvision==0.11.2 -> pytorch==1.10.1 -> _openmp_mutex[version='>=4.5']
# pytorch==1.10.1 -> _openmp_mutex[version='>=4.5']
#
# Package dataclasses conflicts for:
# tensorboard -> werkzeug[version='>=1.0.1'] -> dataclasses
# torchaudio==0.10.1 -> pytorch==1.10.1 -> dataclasses
# torchvision==0.11.2 -> pytorch==1.10.1 -> dataclasses
# iopath -> dataclasses
# wandb -> yaspin[version='>=1.0.0'] -> dataclasses[version='>=0.8,<0.9']
# pytorch==1.10.1 -> dataclasses
#
# Package _libgcc_mutex conflicts for:
# python=3.7 -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# cudatoolkit==11.3.1 -> libgcc-ng[version='>=10.3.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# grpcio -> libgcc-ng[version='>=12'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# pandas==1.4.1 -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# tensorboard -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1|0.1',build='conda_forge|main|main']
# scipy==1.7.3 -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# pytorch==1.10.1 -> _openmp_mutex[version='>=4.5'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# scikit-learn==1.0.2 -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# numpy==1.21.2 -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# grpcio-tools -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# protobuf==3.19.4 -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
# torchvision==0.11.2 -> libgcc-ng[version='>=9.4.0'] -> _libgcc_mutex[version='*|0.1',build='conda_forge|main|main']
#
# Package pypy3.8 conflicts for:
# protobuf==3.19.4 -> setuptools -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# grpcio -> setuptools -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# wandb -> click[version='>=7.0,!=8.0.0'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# pympler -> python -> pypy3.8[version='7.3.8.*|7.3.9.*']
# tensorboardx -> numpy -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# scikit-learn==1.0.2 -> numpy[version='>=1.19.5,<2.0a0'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# pandas==1.4.1 -> numpy[version='>=1.21.5,<2.0a0'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# fvcore -> numpy -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# torchvision==0.11.2 -> numpy[version='>=1.11'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# setuptools==61.2.0 -> pypy3.8[version='>=7.3.8']
# pytorch==1.10.1 -> python[version='>=3.8,<3.9.0a0'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# iopath -> python[version='>=3.6'] -> pypy3.8[version='7.3.8.*|7.3.9.*']
# grpcio-tools -> protobuf[version='>=3.6.0'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# scipy==1.7.3 -> numpy[version='>=1.21.4,<2.0a0'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# tensorboard -> numpy[version='>=1.12.0'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# torchaudio==0.10.1 -> numpy[version='>=1.11'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.8|>=7.3.9']
# numpy==1.21.2 -> python[version='>=3.8,<3.9.0a0'] -> pypy3.8[version='7.3.8.*|7.3.9.*|>=7.3.9']
# setuptools==61.2.0 -> python[version='>=3.8,<3.9.0a0'] -> pypy3.8[version='7.3.*|7.3.8.*|7.3.9.*|>=7.3.9']
#
# Package python-dateutil conflicts for:
# pandas==1.4.1 -> python-dateutil[version='>=2.7.3|>=2.8.1']
# wandb -> python-dateutil[version='>=2.6.1']
#
# Package libprotobuf conflicts for:
# wandb -> protobuf[version='>=3.12.0'] -> libprotobuf[version='3.10.0.*|3.10.1.*|3.11.0.*|3.11.1.*|3.11.2.*|3.11.3.*|3.11.4.*|3.12.1.*|3.12.3.*|3.12.4.*|3.13.0.*|3.13.0.1.*|3.14.0.*|3.15.0.*|3.15.1.*|3.15.2.*|3.15.3.*|3.15.4.*|3.15.5.*|3.15.6.*|3.15.7.*|3.15.8.*|3.16.0.*|3.17.0.*|3.17.1.*|3.17.2.*|3.18.0.*|3.18.1.*|3.19.1.*|3.19.2.*|3.19.3.*|3.19.4.*|3.20.0.*|3.20.1.*|>=3.20.1,<3.21.0a0|>=3.20.0,<3.21.0a0|>=3.19.4,<3.20.0a0|>=3.19.3,<3.20.0a0|>=3.19.2,<3.20.0a0|>=3.19.1,<3.20.0a0|>=3.18.1,<3.19.0a0|>=3.18.0,<3.19.0a0|>=3.17.2,<3.18.0a0|>=3.17.1,<3.18.0a0|>=3.17.0,<3.18.0a0|>=3.16.0,<3.17.0a0|>=3.15.8,<3.16.0a0|>=3.15.7,<3.16.0a0|>=3.15.6,<3.16.0a0|>=3.15.5,<3.16.0a0|>=3.15.4,<3.16.0a0|>=3.15.3,<3.16.0a0|>=3.15.2,<3.16.0a0|>=3.15.1,<3.16.0a0|>=3.15.0,<3.16.0a0|>=3.14.0,<3.15.0a0|>=3.13.0.1,<3.14.0a0|>=3.13.0,<3.14.0a0|>=3.12.4,<3.13.0a0|>=3.12.3,<3.13.0a0|>=3.12.1,<3.13.0a0|>=3.11.4,<3.12.0a0|>=3.11.3,<3.12.0a0|>=3.11.2,<3.12.0a0|>=3.11.1,<3.12.0a0|>=3.11.0,<3.12.0a0|>=3.10.1,<3.11.0a0|>=3.10.0,<3.11.0a0|3.9.2.*|>=3.9.2,<3.10.0a0|3.9.1.*|>=3.9.1,<3.10.0a0|3.9.0.*|>=3.9.0,<3.10.0a0|3.8.0.*|>=3.8.0,<3.9.0a0|3.7.1.*|>=3.7.1,<3.8.0a0|3.7.0.*|>=3.7.0,<3.7.1.0a0|3.6.1.*|>=3.6.1,<3.6.2.0a0|3.6.0.*|>=3.6.0,<3.6.1.0a0|3.5.2.*|3.5.2|3.5.1.1|3.5.1|>=3.5.2,<3.6.0a0|>=3.5.1,<3.6.0a0|>=3.4.1,<3.5.0a0']
<3.13.0a0|>=3.12.3,<3.13.0a0|>=3.12.1,<3.13.0a0|>=3.11.4,<3.12.0a0|>=3.11.3,<3.12.0a0|>=3.11.2,<3.12.0a0|>=3.11.1,<3.12.0a0|>=3.11.0,<3.12.0a0|>=3.10.1,<3.11.0a0|>=3.10.0,<3.11.0a0|3.9.2.*|>=3.9.2,<3.10.0a0|3.9.1.*|>=3.9.1,<3.10.0a0|3.9.0.*|>=3.9.0,<3.10.0a0|3.8.0.*|>=3.8.0,<3.9.0a0|3.7.1.*|>=3.7.1,<3.8.0a0|3.7.0.*|>=3.7.0,<3.7.1.0a0|3.6.1.*|>=3.6.1,<3.6.2.0a0|3.6.0.*|>=3.6.0,<3.6.1.0a0|3.5.2.*|3.5.2|3.5.1.1|3.5.1|>=3.5.2,<3.6.0a0|>=3.5.1,<3.6.0a0|>=3.4.1,<3.5.0a0']
# pytorch==1.10.1 -> libprotobuf[version='>=3.19.3,<3.20.0a0']
# torchaudio==0.10.1 -> pytorch==1.10.1 -> libprotobuf[version='>=3.19.3,<3.20.0a0']
#
# Package openblas conflicts for:
# numpy==1.21.2 -> libblas[version='>=3.8.0,<4.0a0'] -> openblas[version='0.3.5.*|>=0.3.6,<0.3.7.0a0']
# scipy==1.7.3 -> libblas[version='>=3.8.0,<4.0a0'] -> openblas[version='0.3.5.*|>=0.3.6,<0.3.7.0a0']
# torchvision==0.11.2 -> numpy[version='>=1.11'] -> openblas[version='0.2.18.*|0.2.18|0.2.18.*|0.2.19|0.2.19.*|0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0|>=0.2.15']
# torchaudio==0.10.1 -> numpy[version='>=1.11'] -> openblas[version='0.2.18.*|0.2.18|0.2.18.*|0.2.19|0.2.19.*|0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0|>=0.2.15']
# scikit-learn==1.0.2 -> scipy -> openblas[version='0.2.18.*|0.2.18|0.2.18.*|0.2.19|0.2.19.*|0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
# tensorboardx -> numpy -> openblas[version='0.2.18.*|0.2.18|0.2.18.*|0.2.19|0.2.19.*|0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0|>=0.2.15']
# fvcore -> numpy -> openblas[version='0.2.18.*|0.2.18|0.2.18.*|0.2.19|0.2.19.*|0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0|>=0.2.15']
# tensorboard -> numpy[version='>=1.12.0'] -> openblas[version='0.2.18.*|0.2.18|0.2.18.*|0.2.19|0.2.19.*|0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0|>=0.2.15']
#
# Package expat conflicts for:
# python=3.7 -> pypy3.7=7.3.7 -> expat[version='>=2.2.9,<3.0.0a0|>=2.3.0,<3.0a0|>=2.4.1,<3.0a0']
# setuptools==61.2.0 -> pypy3.8[version='>=7.3.8'] -> expat[version='>=2.4.1,<3.0a0|>=2.4.7,<3.0a0|>=2.4.8,<3.0a0']
# scipy==1.7.3 -> pypy3.7[version='>=7.3.7'] -> expat[version='>=2.4.1,<3.0a0']
# scikit-learn==1.0.2 -> pypy3.7[version='>=7.3.7'] -> expat[version='>=2.4.1,<3.0a0']
# numpy==1.21.2 -> pypy3.7[version='>=7.3.5'] -> expat[version='>=2.4.1,<3.0a0']
# protobuf==3.19.4 -> pypy3.7[version='>=7.3.7'] -> expat[version='>=2.4.1,<3.0a0']
#
# Package pyyaml conflicts for:
# fvcore -> yacs[version='>=0.1.6'] -> pyyaml
# fvcore -> pyyaml[version='>=5.1']
#
# Package numpy conflicts for:
# tensorboardx -> numpy
# torchvision==0.11.2 -> pytorch=[build=cuda*] -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.17.5,<2.0a0|>=1.21.5,<2.0a0|>=1.21.6,<2.0a0|>=1.19.4,<2.0a0|>=1.21.2,<2.0a0|>=1.16.5,<2.0a0']
# pandas==1.4.1 -> bottleneck[version='>=1.3.1'] -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0|>=1.21.3,<2.0a0|>=1.18.1,<2.0a0|>=1.21.4,<2.0a0|>=1.19.4,<2.0a0']
# pandas==1.4.1 -> numpy[version='>=1.18.5,<2.0a0|>=1.19.5,<2.0a0|>=1.21.5,<2.0a0|>=1.19.2,<2.0a0|>=1.21.2,<2.0a0']
# scikit-learn==1.0.2 -> scipy -> numpy[version='1.10.*|1.11.*|1.12.*|1.13.*|>=1.11|>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.5,<2.0a0|>=1.17.5,<2.0a0|>=1.21.4,<2.0a0|>=1.21.6,<2.0a0|>=1.19.4,<2.0a0|>=1.19.2,<2.0a0|>=1.18.1,<2.0a0|>=1.9.3,<2.0a0|>=1.9|>=1.21.2,<2.0a0|>=1.15.1,<2.0a0']
# torchaudio==0.10.1 -> pytorch==1.10.1 -> numpy[version='>=1.18.5,<2.0a0|>=1.19.5,<2.0a0']
# scikit-learn==1.0.2 -> numpy[version='>=1.16.6,<2.0a0|>=1.18.5,<2.0a0|>=1.19.5,<2.0a0|>=1.21.5,<2.0a0']
# fvcore -> numpy
# torchvision==0.11.2 -> numpy[version='>=1.11|>=1.18.5,<2.0a0|>=1.19.5,<2.0a0']
# torchaudio==0.10.1 -> numpy[version='>=1.11']
# tensorboard -> numpy[version='>=1.12|>=1.12.0|>=1.16']
# scipy==1.7.3 -> numpy[version='>=1.16.6,<2.0a0|>=1.18.5,<2.0a0|>=1.19.5,<2.0a0|>=1.21.4,<2.0a0|>=1.21.2,<2.0a0']
# pytorch==1.10.1 -> numpy[version='>=1.18.5,<2.0a0|>=1.19.5,<2.0a0']
#
# Package ca-certificates conflicts for:
# python=3.7 -> openssl[version='>=1.1.1l,<1.1.2a'] -> ca-certificates
# grpcio-tools -> python[version='>=2.7,<2.8.0a0'] -> ca-certificates
# wandb -> python -> ca-certificates
# tensorboard -> python[version='>=2.7,<2.8.0a0'] -> ca-certificates
# tensorboardx -> python -> ca-certificates
# grpcio -> openssl[version='>=3.0.3,<4.0a0'] -> ca-certificates
# pympler -> python -> ca-certificates
#
# Package cudatoolkit conflicts for:
# torchaudio==0.10.1 -> cudatoolkit[version='>=10.2,<10.3|>=11.1,<11.2|>=11.3,<11.4']
# torchvision==0.11.2 -> cudatoolkit[version='10.2|10.2.*|11.0|11.0.*|11.1|11.1.*|>=10.2,<10.3|>=11.1,<11.2|>=11.3,<11.4|>=11.2,<12']
# torchaudio==0.10.1 -> pytorch==1.10.1 -> cudatoolkit[version='10.2|10.2.*|11.0|11.0.*|11.1|11.1.*|>=11.2,<12']
# pytorch==1.10.1 -> cudatoolkit[version='10.2|10.2.*|11.0|11.0.*|>=10.2,<10.3|>=11.1,<11.2|>=11.3,<11.4|11.1|11.1.*|>=11.2,<12']
# pytorch==1.10.1 -> cudnn[version='>=8.2.1.32,<9.0a0'] -> cudatoolkit[version='10.0|10.0.*|10.1|10.1.*|10.2.*|11.*|>=11.2,<12.0a0|9.2|9.2.*']
# torchvision==0.11.2 -> cudnn[version='>=8.2.1.32,<9.0a0'] -> cudatoolkit[version='10.0.*|10.0|10.0.*|10.1|10.1.*|10.2.*|11.*|9.2|9.2.*|>=11.2,<12.0a0|>=10.1.243,<10.2.0a0|>=9.2,<9.3.0a0|>=10.0.130,<10.1.0a0|9.2.*|>=9.0,<9.1.0a0|>=8.0,<8.1.0a0']
#
# Package llvm-openmp conflicts for:
# scikit-learn==1.0.2 -> _openmp_mutex -> llvm-openmp[version='>=9.0.1']
# numpy==1.21.2 -> mkl[version='>=2021.4.0,<2022.0a0'] -> llvm-openmp[version='>=10.0.0|>=11.0.0|>=11.0.1|>=11.1.0|>=12.0.1|>=13.0.1|>=9.0.1|>=10.0.1']
# scipy==1.7.3 -> blas=[build=openblas] -> llvm-openmp[version='>=10.0.0|>=11.0.0|>=11.0.1|>=11.1.0|>=12.0.1|>=13.0.1|>=9.0.1|>=10.0.1']
# pytorch==1.10.1 -> blas=[build=mkl] -> llvm-openmp[version='>=10.0.0|>=11.0.0|>=11.0.1|>=11.1.0|>=12.0.1|>=13.0.1|>=14.0.3|>=9.0.1']
#
# Package colorama conflicts for:
# fvcore -> tqdm -> colorama
# iopath -> tqdm -> colorama
#
# Package wheel conflicts for:
# python=3.7 -> pip -> wheel
# tensorboard -> wheel[version='>=0.26']
#
# Package libgomp conflicts for:
# pytorch==1.10.1 -> _openmp_mutex[version='>=4.5'] -> libgomp[version='>=7.3.0|>=7.5.0']
# scikit-learn==1.0.2 -> _openmp_mutex -> libgomp[version='>=7.3.0|>=7.5.0']
#
# Package liblapacke conflicts for:
# numpy==1.21.2 -> blas=[build=openblas] -> liblapacke[version='3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.9.0|3.9.0|3.9.0|3.9.0',build='2_openblas|3_openblas|6_openblas|10_openblas|11_openblas|13_openblas|15_openblas|16_openblas|5_openblas|9_openblas|10_openblas|12_linux64_openblas|13_linux64_openblas|14_linux64_openblas|11_linux64_openblas|8_openblas|7_openblas|6_openblas|17_openblas|14_openblas|12_openblas|9_openblas|8_openblas|7_openblas|5_openblas|4_openblas|0_openblas']
# scipy==1.7.3 -> blas=[build=openblas] -> liblapacke[version='3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.9.0|3.9.0|3.9.0|3.9.0',build='2_openblas|3_openblas|6_openblas|10_openblas|11_openblas|13_openblas|15_openblas|16_openblas|5_openblas|9_openblas|10_openblas|12_linux64_openblas|13_linux64_openblas|14_linux64_openblas|11_linux64_openblas|8_openblas|7_openblas|6_openblas|17_openblas|14_openblas|12_openblas|9_openblas|8_openblas|7_openblas|5_openblas|4_openblas|0_openblas']
# pytorch==1.10.1 -> blas=[build=mkl] -> liblapacke[version='3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.8.0|3.9.0',build='4_mkl|8_mkl|9_mkl|10_mkl|11_mkl|13_mkl|19_mkl|20_mkl|21_mkl|5_mkl|7_mkl|8_mkl|9_mkl|12_linux64_mkl|13_linux64_mkl|14_linux64_mkl|11_linux64_mkl|10_mkl|6_mkl|18_mkl|16_mkl|15_mkl|14_mkl|12_mkl|7_mkl|6_mkl|5_mkl']
#
# Package idna conflicts for:
# tensorboard -> requests[version='>=2.21.0,<3'] -> idna[version='>=2.5,<2.9|>=2.5,<3|>=2.5,<4']
# wandb -> requests[version='>=2.0.0,<3'] -> idna[version='>=2.5,<2.6|>=2.5,<2.7|>=2.5,<2.8|>=2.5,<2.9|>=2.5,<3|>=2.5,<4']
#
# Package pytorch conflicts for:
# torchaudio==0.10.1 -> pytorch==1.10.1
# torchvision==0.11.2 -> pytorch-cpu -> pytorch[version='1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.0|1.10.1|1.10.1|1.10.1|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.11.0|1.9.1|1.9.1|1.9.1|1.9.1|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.6.0|1.6.0|1.6.0|1.6|1.3.1.*|1.2.0.*|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.11.0|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.2|1.10.1|1.10.1|1.10.1|1.10.1|1.10.1|1.10.1|1.10.1|1.10.1|1.10.1|1.10.1|1.10.1|1.10.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.1|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.9.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.8.0|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.7.1|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.0|1.6.
# torchvision==0.11.2 -> pytorch[version='*|*|1.10|1.10|1.10.1|1.10.0.*',build='cpu*|cuda*|cuda*|cpu*']
#
# Package typing-extensions conflicts for:
# torchvision==0.11.2 -> pytorch=[build=cpu*] -> typing-extensions
# wandb -> gitpython[version='>=1.0.0'] -> typing-extensions[version='>=3.7.4.0']
#
# Package libtiff conflicts for:
# fvcore -> pillow -> libtiff[version='4.*|4.0.*|>=4.0.10,<4.4.0a0|>=4.1.0,<4.4.0a0|>=4.2.0,<4.4.0a0|>=4.3.0,<4.4.0a0|>=4.3.0,<5.0a0|>=4.0.9,<4.4.0a0|>=4.0.8,<4.0.10|>=4.0.3,<4.0.8|4.0.6|>=4.1.0,<5.0a0|>=4.0.10,<5.0a0|>=4.0.9,<5.0a0|>=4.0.8,<5.0a0']
# torchvision==0.11.2 -> pillow[version='>=5.3.0'] -> libtiff[version='>=4.0.10,<4.4.0a0|>=4.1.0,<4.4.0a0|>=4.2.0,<4.4.0a0|>=4.3.0,<4.4.0a0|>=4.3.0,<5.0a0|>=4.0.9,<4.4.0a0|>=4.1.0,<5.0a0|>=4.0.10,<5.0a0|>=4.0.9,<5.0a0']
#
# Package typing_extensions conflicts for:
# torchvision==0.11.2 -> pytorch==1.10.1 -> typing_extensions
# pytorch==1.10.1 -> typing_extensions
# wandb -> gitpython[version='>=1.0.0'] -> typing_extensions[version='>=3.7.4.3']
# torchaudio==0.10.1 -> pytorch==1.10.1 -> typing_extensions
#
# Package packaging conflicts for:
# pandas==1.4.1 -> numexpr[version='>=2.7.1'] -> packaging
# tensorboard -> wheel[version='>=0.26'] -> packaging[version='>=20.2']
#
# Package requests conflicts for:
# tensorboard -> google-auth[version='>=1.6.3,<3'] -> requests[version='>=2.20.0,<3.0.0dev']
# tensorboard -> requests[version='>=2.21.0|>=2.21.0,<3']
#
# Package grpcio conflicts for:
# tensorboard -> grpcio[version='>=1.14|>=1.24.3|>=1.6.3']
# grpcio-tools -> grpcio[version='1.33.2|1.41.1|1.35.0|>=1.16.1']
#
# Package typing conflicts for:
# pytorch==1.10.1 -> typing_extensions -> typing[version='>=3.6.2|>=3.7.4']
# wandb -> promise[version='>=2.0,<3'] -> typing[version='>=3.6.4']
# torchvision==0.11.2 -> pytorch=[build=cuda*] -> typingThe following specifications were found to be incompatible with your system:
#
#   - feature:/linux-64::__glibc==2.27=0
#   - feature:|@/linux-64::__glibc==2.27=0
#   - cudatoolkit==11.3.1 -> __glibc[version='>=2.17,<3.0.a0']
#   - cudatoolkit==11.3.1 -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - grpcio -> libgcc-ng[version='>=9.3.0'] -> __glibc[version='>=2.17']
#   - grpcio-tools -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - numpy==1.21.2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pandas==1.4.1 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - pytorch==1.10.1 -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - scikit-learn==1.0.2 -> libgcc-ng[version='>=7.5.0'] -> __glibc[version='>=2.17']
#   - scipy==1.7.3 -> libgfortran-ng -> __glibc[version='>=2.17']
#   - tensorboard -> libgcc-ng[version='>=7.3.0'] -> __glibc[version='>=2.17']
#   - torchaudio==0.10.1 -> cudatoolkit[version='>=11.1,<11.2'] -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#   - torchvision==0.11.2 -> __glibc[version='>=2.17|>=2.17,<3.0.a0']
#
# Your installed version is: 2.27
